# %%
# !pip install pydot

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### LOAD DATASET

# %%
# helper functions
def DataLoading (mypath):
    print ("Loading the data")
    dataframe = pd.read_csv(mypath,header = None,engine = 'python',sep=",")
    return dataframe


# column names
def prepate_dataset(df):
  column_names = ["duration", "protocol_type", "service", "flag" ,"src_bytes",
                  "dst_bytes", "land", "wrong_fragment", "urgent", "hot", "num_failed_logins",
                  "logged_in", "num_compromised", "root_shell", "su_attempted", "num_root", 
                  "num_file_creations", "num_shells", "num_access_files", "num_outbound_cmds",
                  "is_host_login", "is_guest_login", "count", "srv_count", "serror_rate", 
                  "srv_error_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate", 
                  "diff_srv_rate", "srv_diff_host_rate", "dst_host_count", "dst_host_srv_count",
                  "dst_host_same_srv_rate", "dst_host_diff_srv_rate", "dst_host_same_src_port_rate",
                  "dst_host_srv_diff_host_rate", "dst_host_serror_rate", "dst_host_srv_serror_rate",
                  "dst_host_rerror_rate", "dst_host_srv_rerror_rate", "attack", "difficulty"]

  # assigning the column names
  df.columns = column_names

  # preparing class labels 
  df['class'] = df['attack'].replace(['back', 'land', 'neptune', 'pod','smurf', 'teardrop'],'attack') # Dos
  df['class'] = df['class'].replace(['ipsweep', 'nmap','portsweep', 'satan'],'attack') # Probe
  df['class'] = df['class'].replace(['buffer_overflow','loadmodule', 'perl','rootkit'],'attack') # U2R
  df['class'] = df['class'].replace(['ftp_write', 'guess_passwd','imap', 'multihop', 'phf','spy', 'warezclient','warezmaster'],'attack') # R2L

  # droping attacks column
  df = df.drop(['attack'], axis=1)
  df = df.drop(['difficulty'], axis=1)
  # Creating a instance of label Encoder.
  le = LabelEncoder()
  
  # Using .fit_transform function to fit label
  # encoder and return encoded label
  df['protocol_type'] = le.fit_transform(df['protocol_type'])
  df['service'] = le.fit_transform(df['service'])
  df['flag'] = le.fit_transform(df['flag'])
  df['class'] = le.fit_transform(df['class'])

  return df

# %%
df_train = DataLoading("./NSL-KDD/KDDTrain+.txt")
df_train = prepate_dataset(df_train)


df_val = DataLoading("./NSL-KDD/KDDTrain+_20Percent.txt")
df_val = prepate_dataset(df_val)
# Out:
# Loading the data
# Loading the data

# %% [markdown]
# #### Pre-Precess DATA

# %%
# divide to train and test arrays 

x_train = df_train.drop(['class'], axis=1).to_numpy()
y_train = df_train['class'].to_numpy()

x_test = df_val.drop(['class'], axis=1).to_numpy()
y_test = df_val['class'].to_numpy()

print(x_train.shape, y_train.shape,  x_test.shape, y_test.shape)
# Out:
# (125973, 41) (125973,) (25192, 41) (25192,)

# %%
# normalize the data

norm = np.linalg.norm(x_train)
x_train = x_train/norm

norm = np.linalg.norm(x_test)
x_test = x_test/norm

# %%
# reshape to fit in lstm

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# #### LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, Bidirectional, Flatten,Embedding
from keras.utils import plot_model
# Out:
# 2022-09-30 05:36:02.181967: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Sequential()
model.add(Bidirectional(GRU(64, return_sequences=True),input_shape=(41, 1)))
model.add(Dropout(0.2))


model.add(Bidirectional(GRU(32)))
model.add(Dropout(0.2))


model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 41, 128)          25728
#  nal)
#
#  dropout_8 (Dropout)         (None, 41, 128)           0
#
#  bidirectional_3 (Bidirectio  (None, 64)               31104
#  nal)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
#  dropout_14 (Dropout)        (None, 1)                 0
#
#  dense_12 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 73,539
# Trainable params: 73,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6)

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy'],
)

model.fit(x_train,
          y_train,
          epochs=100,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.6787 - accuracy: 0.2048 - val_loss: 0.6735 - val_accuracy: 0.2067
# Epoch 2/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.6784 - accuracy: 0.2105 - val_loss: 0.6643 - val_accuracy: 0.215
# Epoch 3/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.6696 - accuracy: 0.2149 - val_loss: 0.6576 - val_accuracy: 0.2161
# Epoch 4/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.6621 - accuracy: 0.2209 - val_loss: 0.6542 - val_accuracy: 0.2235
# Epoch 5/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.6596 - accuracy: 0.2306 - val_loss: 0.6478 - val_accuracy: 0.23
# Epoch 6/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.656 - accuracy: 0.233 - val_loss: 0.6453 - val_accuracy: 0.2371
# Epoch 7/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.6468 - accuracy: 0.2338 - val_loss: 0.6437 - val_accuracy: 0.2418
# Epoch 8/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.6412 - accuracy: 0.2366 - val_loss: 0.6394 - val_accuracy: 0.2504
# Epoch 9/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6324 - accuracy: 0.2408 - val_loss: 0.6296 - val_accuracy: 0.2586
# Epoch 10/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.6299 - accuracy: 0.2459 - val_loss: 0.6275 - val_accuracy: 0.26
# Epoch 11/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.6288 - accuracy: 0.2524 - val_loss: 0.6175 - val_accuracy: 0.2612
# Epoch 12/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.6239 - accuracy: 0.2548 - val_loss: 0.608 - val_accuracy: 0.2625
# Epoch 13/100
# 3937/3937 [==============================] - 134s 32ms/step - loss: 0.623 - accuracy: 0.2584 - val_loss: 0.6042 - val_accuracy: 0.2637
# Epoch 14/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.6201 - accuracy: 0.2644 - val_loss: 0.5943 - val_accuracy: 0.2655
# Epoch 15/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.613 - accuracy: 0.2711 - val_loss: 0.5874 - val_accuracy: 0.2709
# Epoch 16/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.6126 - accuracy: 0.2785 - val_loss: 0.5821 - val_accuracy: 0.2799
# Epoch 17/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.6067 - accuracy: 0.2814 - val_loss: 0.5766 - val_accuracy: 0.2839
# Epoch 18/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.6045 - accuracy: 0.2864 - val_loss: 0.5736 - val_accuracy: 0.29
# Epoch 19/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.5996 - accuracy: 0.2935 - val_loss: 0.5727 - val_accuracy: 0.2973
# Epoch 20/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.5938 - accuracy: 0.2997 - val_loss: 0.5644 - val_accuracy: 0.3062
# Epoch 21/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.592 - accuracy: 0.3019 - val_loss: 0.5579 - val_accuracy: 0.3151
# Epoch 22/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.5861 - accuracy: 0.309 - val_loss: 0.5579 - val_accuracy: 0.3225
# Epoch 23/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.5838 - accuracy: 0.3103 - val_loss: 0.5495 - val_accuracy: 0.3254
# Epoch 24/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5836 - accuracy: 0.3129 - val_loss: 0.5474 - val_accuracy: 0.3339
# Epoch 25/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.5741 - accuracy: 0.3218 - val_loss: 0.5461 - val_accuracy: 0.3427
# Epoch 26/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.5675 - accuracy: 0.3302 - val_loss: 0.5408 - val_accuracy: 0.344
# Epoch 27/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.563 - accuracy: 0.3393 - val_loss: 0.5344 - val_accuracy: 0.3534
# Epoch 28/100
# 3937/3937 [==============================] - 134s 32ms/step - loss: 0.554 - accuracy: 0.3488 - val_loss: 0.5316 - val_accuracy: 0.3565
# Epoch 29/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.5495 - accuracy: 0.3503 - val_loss: 0.5278 - val_accuracy: 0.3665
# Epoch 30/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.546 - accuracy: 0.358 - val_loss: 0.5215 - val_accuracy: 0.3763
# Epoch 31/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.5434 - accuracy: 0.3625 - val_loss: 0.5145 - val_accuracy: 0.3859
# Epoch 32/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5342 - accuracy: 0.3705 - val_loss: 0.5114 - val_accuracy: 0.3933
# Epoch 33/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.5269 - accuracy: 0.3716 - val_loss: 0.5018 - val_accuracy: 0.3977
# Epoch 34/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.524 - accuracy: 0.3815 - val_loss: 0.4996 - val_accuracy: 0.4013
# Epoch 35/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.5171 - accuracy: 0.3866 - val_loss: 0.4975 - val_accuracy: 0.4071
# Epoch 36/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.5133 - accuracy: 0.3904 - val_loss: 0.494 - val_accuracy: 0.4109
# Epoch 37/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.5086 - accuracy: 0.3984 - val_loss: 0.4859 - val_accuracy: 0.4169
# Epoch 38/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.5018 - accuracy: 0.4003 - val_loss: 0.4806 - val_accuracy: 0.42
# Epoch 39/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.4958 - accuracy: 0.4051 - val_loss: 0.4773 - val_accuracy: 0.4223
# Epoch 40/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.4917 - accuracy: 0.4113 - val_loss: 0.4766 - val_accuracy: 0.4232
# Epoch 41/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.4895 - accuracy: 0.4187 - val_loss: 0.4748 - val_accuracy: 0.4263
# Epoch 42/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.4885 - accuracy: 0.419 - val_loss: 0.4676 - val_accuracy: 0.4278
# Epoch 43/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4848 - accuracy: 0.4283 - val_loss: 0.4587 - val_accuracy: 0.4324
# Epoch 44/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.4814 - accuracy: 0.4336 - val_loss: 0.4551 - val_accuracy: 0.4378
# Epoch 45/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.4761 - accuracy: 0.4421 - val_loss: 0.4462 - val_accuracy: 0.444
# Epoch 46/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.4753 - accuracy: 0.4423 - val_loss: 0.445 - val_accuracy: 0.4461
# Epoch 47/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.4741 - accuracy: 0.4498 - val_loss: 0.4436 - val_accuracy: 0.4475
# Epoch 48/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.4676 - accuracy: 0.456 - val_loss: 0.435 - val_accuracy: 0.4506
# Epoch 49/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.4676 - accuracy: 0.4582 - val_loss: 0.4308 - val_accuracy: 0.4518
# Epoch 50/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.4576 - accuracy: 0.4609 - val_loss: 0.4291 - val_accuracy: 0.4611
# Epoch 51/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.4554 - accuracy: 0.4685 - val_loss: 0.4225 - val_accuracy: 0.4705
# Epoch 52/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.4455 - accuracy: 0.4696 - val_loss: 0.4209 - val_accuracy: 0.4714
# Epoch 53/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.4415 - accuracy: 0.4795 - val_loss: 0.417 - val_accuracy: 0.4762
# Epoch 54/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.4367 - accuracy: 0.4803 - val_loss: 0.4169 - val_accuracy: 0.4792
# Epoch 55/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.4276 - accuracy: 0.4868 - val_loss: 0.4159 - val_accuracy: 0.4823
# Epoch 56/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.4192 - accuracy: 0.4914 - val_loss: 0.4077 - val_accuracy: 0.4881
# Epoch 57/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.4101 - accuracy: 0.5004 - val_loss: 0.4062 - val_accuracy: 0.4965
# Epoch 58/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.4081 - accuracy: 0.509 - val_loss: 0.3966 - val_accuracy: 0.4985
# Epoch 59/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3989 - accuracy: 0.5094 - val_loss: 0.3911 - val_accuracy: 0.5078
# Epoch 60/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.3925 - accuracy: 0.5163 - val_loss: 0.3879 - val_accuracy: 0.5177
# Epoch 61/100
# 3937/3937 [==============================] - 135s 32ms/step - loss: 0.3837 - accuracy: 0.5188 - val_loss: 0.3827 - val_accuracy: 0.5223
# Epoch 62/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.3769 - accuracy: 0.5237 - val_loss: 0.3789 - val_accuracy: 0.5311
# Epoch 63/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.3746 - accuracy: 0.5274 - val_loss: 0.3693 - val_accuracy: 0.5375
# Epoch 64/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.3738 - accuracy: 0.5298 - val_loss: 0.36 - val_accuracy: 0.5405
# Epoch 65/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.3692 - accuracy: 0.5303 - val_loss: 0.3534 - val_accuracy: 0.5419
# Epoch 66/100
# 3937/3937 [==============================] - 134s 32ms/step - loss: 0.3683 - accuracy: 0.5327 - val_loss: 0.3442 - val_accuracy: 0.5499
# Epoch 67/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.3596 - accuracy: 0.5395 - val_loss: 0.3373 - val_accuracy: 0.5591
# Epoch 68/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.3595 - accuracy: 0.542 - val_loss: 0.3279 - val_accuracy: 0.5648
# Epoch 69/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.3508 - accuracy: 0.5491 - val_loss: 0.318 - val_accuracy: 0.5662
# Epoch 70/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.3481 - accuracy: 0.5574 - val_loss: 0.3109 - val_accuracy: 0.5736
# Epoch 71/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.3431 - accuracy: 0.5656 - val_loss: 0.3106 - val_accuracy: 0.5802
# Epoch 72/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.337 - accuracy: 0.5725 - val_loss: 0.309 - val_accuracy: 0.5864
# Epoch 73/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.3305 - accuracy: 0.5745 - val_loss: 0.3039 - val_accuracy: 0.5963
# Epoch 74/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.3244 - accuracy: 0.5753 - val_loss: 0.3001 - val_accuracy: 0.6046
# Epoch 75/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.3202 - accuracy: 0.578 - val_loss: 0.2972 - val_accuracy: 0.6089
# Epoch 76/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.3185 - accuracy: 0.5874 - val_loss: 0.2955 - val_accuracy: 0.6157
# Epoch 77/100
# 3937/3937 [==============================] - 134s 32ms/step - loss: 0.3085 - accuracy: 0.5968 - val_loss: 0.2932 - val_accuracy: 0.625
# Epoch 78/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3003 - accuracy: 0.5991 - val_loss: 0.285 - val_accuracy: 0.6346
# Epoch 79/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.2924 - accuracy: 0.605 - val_loss: 0.2785 - val_accuracy: 0.6353
# Epoch 80/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2921 - accuracy: 0.6062 - val_loss: 0.2719 - val_accuracy: 0.6434
# Epoch 81/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.2846 - accuracy: 0.6076 - val_loss: 0.2623 - val_accuracy: 0.6518
# Epoch 82/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.2845 - accuracy: 0.6127 - val_loss: 0.2548 - val_accuracy: 0.6523
# Epoch 83/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.2787 - accuracy: 0.6207 - val_loss: 0.2495 - val_accuracy: 0.6562
# Epoch 84/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.2763 - accuracy: 0.6266 - val_loss: 0.2436 - val_accuracy: 0.666
# Epoch 85/100
# 3937/3937 [==============================] - 137s 32ms/step - loss: 0.2711 - accuracy: 0.6365 - val_loss: 0.2356 - val_accuracy: 0.6759
# Epoch 86/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2625 - accuracy: 0.6426 - val_loss: 0.2341 - val_accuracy: 0.6773
# Epoch 87/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2622 - accuracy: 0.6491 - val_loss: 0.2326 - val_accuracy: 0.6862
# Epoch 88/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.259 - accuracy: 0.653 - val_loss: 0.2326 - val_accuracy: 0.6908
# Epoch 89/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.2528 - accuracy: 0.6624 - val_loss: 0.2317 - val_accuracy: 0.7004
# Epoch 90/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.246 - accuracy: 0.6714 - val_loss: 0.2296 - val_accuracy: 0.7076
# Epoch 91/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2396 - accuracy: 0.6795 - val_loss: 0.2238 - val_accuracy: 0.7119
# Epoch 92/100
# 3937/3937 [==============================] - 133s 32ms/step - loss: 0.2338 - accuracy: 0.6869 - val_loss: 0.2196 - val_accuracy: 0.7189
# Epoch 93/100
# 3937/3937 [==============================] - 132s 32ms/step - loss: 0.231 - accuracy: 0.6929 - val_loss: 0.213 - val_accuracy: 0.7281
# Epoch 94/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2298 - accuracy: 0.6986 - val_loss: 0.2089 - val_accuracy: 0.7323
# Epoch 95/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2209 - accuracy: 0.7082 - val_loss: 0.2026 - val_accuracy: 0.7366
# Epoch 96/100
# 3937/3937 [==============================] - 138s 32ms/step - loss: 0.2116 - accuracy: 0.7105 - val_loss: 0.1997 - val_accuracy: 0.7376
# Epoch 97/100
# 3937/3937 [==============================] - 130s 32ms/step - loss: 0.2075 - accuracy: 0.711 - val_loss: 0.1958 - val_accuracy: 0.7435
# Epoch 98/100
# 3937/3937 [==============================] - 134s 32ms/step - loss: 0.2011 - accuracy: 0.7142 - val_loss: 0.1947 - val_accuracy: 0.7479
# Epoch 99/100
# 3937/3937 [==============================] - 136s 32ms/step - loss: 0.1944 - accuracy: 0.7178 - val_loss: 0.1921 - val_accuracy: 0.748
# Epoch 100/100
# 3937/3937 [==============================] - 139s 32ms/step - loss: 0.1865 - accuracy: 0.7272 - val_loss: 0.1879 - val_accuracy: 0.7517
