# %%
# !pip install pydot

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### LOAD DATASET

# %%
# helper functions
def DataLoading (mypath):
    print ("Loading the data")
    dataframe = pd.read_csv(mypath,header = None,engine = 'python',sep=",")
    return dataframe


# column names
def prepate_dataset(df):
  column_names = ["duration", "protocol_type", "service", "flag" ,"src_bytes",
                  "dst_bytes", "land", "wrong_fragment", "urgent", "hot", "num_failed_logins",
                  "logged_in", "num_compromised", "root_shell", "su_attempted", "num_root", 
                  "num_file_creations", "num_shells", "num_access_files", "num_outbound_cmds",
                  "is_host_login", "is_guest_login", "count", "srv_count", "serror_rate", 
                  "srv_error_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate", 
                  "diff_srv_rate", "srv_diff_host_rate", "dst_host_count", "dst_host_srv_count",
                  "dst_host_same_srv_rate", "dst_host_diff_srv_rate", "dst_host_same_src_port_rate",
                  "dst_host_srv_diff_host_rate", "dst_host_serror_rate", "dst_host_srv_serror_rate",
                  "dst_host_rerror_rate", "dst_host_srv_rerror_rate", "attack", "difficulty"]

  # assigning the column names
  df.columns = column_names

  # preparing class labels 
  df['class'] = df['attack'].replace(['back', 'land', 'neptune', 'pod','smurf', 'teardrop'],'attack') # Dos
  df['class'] = df['class'].replace(['ipsweep', 'nmap','portsweep', 'satan'],'attack') # Probe
  df['class'] = df['class'].replace(['buffer_overflow','loadmodule', 'perl','rootkit'],'attack') # U2R
  df['class'] = df['class'].replace(['ftp_write', 'guess_passwd','imap', 'multihop', 'phf','spy', 'warezclient','warezmaster'],'attack') # R2L

  # droping attacks column
  df = df.drop(['attack'], axis=1)
  df = df.drop(['difficulty'], axis=1)
  # Creating a instance of label Encoder.
  le = LabelEncoder()
  
  # Using .fit_transform function to fit label
  # encoder and return encoded label
  df['protocol_type'] = le.fit_transform(df['protocol_type'])
  df['service'] = le.fit_transform(df['service'])
  df['flag'] = le.fit_transform(df['flag'])
  df['class'] = le.fit_transform(df['class'])

  return df

# %%
df_train = DataLoading("./NSL-KDD/KDDTrain+.txt")
df_train = prepate_dataset(df_train)


df_val = DataLoading("./NSL-KDD/KDDTrain+_20Percent.txt")
df_val = prepate_dataset(df_val)
# Out:
# Loading the data
# Loading the data

# %% [markdown]
# #### Pre-Precess DATA

# %%
# divide to train and test arrays 

x_train = df_train.drop(['class'], axis=1).to_numpy()
y_train = df_train['class'].to_numpy()

x_test = df_val.drop(['class'], axis=1).to_numpy()
y_test = df_val['class'].to_numpy()

print(x_train.shape, y_train.shape,  x_test.shape, y_test.shape)
# Out:
# (125973, 41) (125973,) (25192, 41) (25192,)

# %%
# normalize the data

norm = np.linalg.norm(x_train)
x_train = x_train/norm

norm = np.linalg.norm(x_test)
x_test = x_test/norm

# %%
# reshape to fit in lstm

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# #### BiGRU

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, Bidirectional, Flatten,Embedding
from keras.utils import plot_model
# Out:
# 2022-09-29 11:24:11.211889: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Sequential()
model.add(Bidirectional(GRU(64, return_sequences=True),input_shape=(41, 1)))
model.add(Dropout(0.2))


model.add(Bidirectional(GRU(32)))
model.add(Dropout(0.2))


model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 41, 128)          25728
#  nal)
#
#  dropout_4 (Dropout)         (None, 41, 128)           0
#
#  bidirectional_4 (Bidirectio  (None, 64)               31104
#  nal)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
#  dropout_11 (Dropout)        (None, 1)                 0
#
#  dense_8 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6)

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy'],
)

model.fit(x_train,
          y_train,
          epochs=100,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6819 - accuracy: 0.4058 - val_loss: 0.6892 - val_accuracy: 0.4003
# Epoch 2/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6755 - accuracy: 0.4146 - val_loss: 0.6856 - val_accuracy: 0.404
# Epoch 3/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6656 - accuracy: 0.416 - val_loss: 0.6812 - val_accuracy: 0.4062
# Epoch 4/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.656 - accuracy: 0.4184 - val_loss: 0.6715 - val_accuracy: 0.4143
# Epoch 5/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6479 - accuracy: 0.4252 - val_loss: 0.6658 - val_accuracy: 0.4227
# Epoch 6/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6381 - accuracy: 0.4347 - val_loss: 0.6622 - val_accuracy: 0.426
# Epoch 7/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6311 - accuracy: 0.4445 - val_loss: 0.6575 - val_accuracy: 0.4311
# Epoch 8/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6229 - accuracy: 0.445 - val_loss: 0.6566 - val_accuracy: 0.4383
# Epoch 9/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6148 - accuracy: 0.4516 - val_loss: 0.6529 - val_accuracy: 0.4475
# Epoch 10/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.614 - accuracy: 0.4568 - val_loss: 0.6481 - val_accuracy: 0.4561
# Epoch 11/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6097 - accuracy: 0.4572 - val_loss: 0.6448 - val_accuracy: 0.4601
# Epoch 12/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.6008 - accuracy: 0.4588 - val_loss: 0.6369 - val_accuracy: 0.4638
# Epoch 13/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5963 - accuracy: 0.4687 - val_loss: 0.627 - val_accuracy: 0.4676
# Epoch 14/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5912 - accuracy: 0.4779 - val_loss: 0.6195 - val_accuracy: 0.471
# Epoch 15/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5882 - accuracy: 0.4811 - val_loss: 0.6143 - val_accuracy: 0.4801
# Epoch 16/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5827 - accuracy: 0.4826 - val_loss: 0.609 - val_accuracy: 0.4859
# Epoch 17/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5781 - accuracy: 0.4844 - val_loss: 0.6006 - val_accuracy: 0.4944
# Epoch 18/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5743 - accuracy: 0.4915 - val_loss: 0.5921 - val_accuracy: 0.5015
# Epoch 19/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5669 - accuracy: 0.5014 - val_loss: 0.5846 - val_accuracy: 0.5083
# Epoch 20/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5649 - accuracy: 0.5034 - val_loss: 0.5825 - val_accuracy: 0.5117
# Epoch 21/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5562 - accuracy: 0.5095 - val_loss: 0.5732 - val_accuracy: 0.5183
# Epoch 22/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5507 - accuracy: 0.5157 - val_loss: 0.5644 - val_accuracy: 0.5207
# Epoch 23/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5427 - accuracy: 0.5158 - val_loss: 0.5555 - val_accuracy: 0.5281
# Epoch 24/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5394 - accuracy: 0.5241 - val_loss: 0.5531 - val_accuracy: 0.5332
# Epoch 25/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5339 - accuracy: 0.5307 - val_loss: 0.5499 - val_accuracy: 0.5376
# Epoch 26/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5336 - accuracy: 0.5328 - val_loss: 0.5426 - val_accuracy: 0.5389
# Epoch 27/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.524 - accuracy: 0.5343 - val_loss: 0.5406 - val_accuracy: 0.5489
# Epoch 28/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5201 - accuracy: 0.5385 - val_loss: 0.533 - val_accuracy: 0.5548
# Epoch 29/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5149 - accuracy: 0.5389 - val_loss: 0.5283 - val_accuracy: 0.5587
# Epoch 30/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5104 - accuracy: 0.5431 - val_loss: 0.5272 - val_accuracy: 0.5666
# Epoch 31/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.5023 - accuracy: 0.5526 - val_loss: 0.5249 - val_accuracy: 0.5716
# Epoch 32/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4983 - accuracy: 0.5567 - val_loss: 0.5214 - val_accuracy: 0.5723
# Epoch 33/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4982 - accuracy: 0.5656 - val_loss: 0.5126 - val_accuracy: 0.5795
# Epoch 34/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4933 - accuracy: 0.5737 - val_loss: 0.5103 - val_accuracy: 0.587
# Epoch 35/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4836 - accuracy: 0.58 - val_loss: 0.5068 - val_accuracy: 0.5894
# Epoch 36/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4799 - accuracy: 0.5808 - val_loss: 0.5018 - val_accuracy: 0.5989
# Epoch 37/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4731 - accuracy: 0.5813 - val_loss: 0.4922 - val_accuracy: 0.6078
# Epoch 38/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4726 - accuracy: 0.5844 - val_loss: 0.4843 - val_accuracy: 0.6091
# Epoch 39/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4652 - accuracy: 0.5881 - val_loss: 0.4745 - val_accuracy: 0.6104
# Epoch 40/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.457 - accuracy: 0.5929 - val_loss: 0.4669 - val_accuracy: 0.615
# Epoch 41/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4528 - accuracy: 0.599 - val_loss: 0.4608 - val_accuracy: 0.6158
# Epoch 42/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4511 - accuracy: 0.6043 - val_loss: 0.4513 - val_accuracy: 0.6204
# Epoch 43/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4443 - accuracy: 0.6062 - val_loss: 0.4477 - val_accuracy: 0.623
# Epoch 44/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4382 - accuracy: 0.6067 - val_loss: 0.4441 - val_accuracy: 0.6255
# Epoch 45/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4378 - accuracy: 0.612 - val_loss: 0.441 - val_accuracy: 0.6315
# Epoch 46/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4338 - accuracy: 0.6141 - val_loss: 0.4409 - val_accuracy: 0.6328
# Epoch 47/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4259 - accuracy: 0.6232 - val_loss: 0.4352 - val_accuracy: 0.6339
# Epoch 48/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4213 - accuracy: 0.6298 - val_loss: 0.4285 - val_accuracy: 0.6361
# Epoch 49/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4192 - accuracy: 0.6336 - val_loss: 0.4277 - val_accuracy: 0.6385
# Epoch 50/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4175 - accuracy: 0.6378 - val_loss: 0.4192 - val_accuracy: 0.6402
# Epoch 51/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4139 - accuracy: 0.6407 - val_loss: 0.4189 - val_accuracy: 0.6421
# Epoch 52/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.4046 - accuracy: 0.6466 - val_loss: 0.4106 - val_accuracy: 0.6447
# Epoch 53/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3974 - accuracy: 0.6515 - val_loss: 0.4013 - val_accuracy: 0.6464
# Epoch 54/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3893 - accuracy: 0.6601 - val_loss: 0.3969 - val_accuracy: 0.654
# Epoch 55/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3801 - accuracy: 0.6655 - val_loss: 0.391 - val_accuracy: 0.6629
# Epoch 56/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3721 - accuracy: 0.6671 - val_loss: 0.3893 - val_accuracy: 0.6715
# Epoch 57/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3696 - accuracy: 0.6733 - val_loss: 0.3884 - val_accuracy: 0.6785
# Epoch 58/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3642 - accuracy: 0.6816 - val_loss: 0.3849 - val_accuracy: 0.6811
# Epoch 59/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3601 - accuracy: 0.6825 - val_loss: 0.3833 - val_accuracy: 0.6887
# Epoch 60/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3593 - accuracy: 0.6885 - val_loss: 0.3793 - val_accuracy: 0.6918
# Epoch 61/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.356 - accuracy: 0.692 - val_loss: 0.373 - val_accuracy: 0.6959
# Epoch 62/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3514 - accuracy: 0.6967 - val_loss: 0.3721 - val_accuracy: 0.6972
# Epoch 63/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3454 - accuracy: 0.6992 - val_loss: 0.3716 - val_accuracy: 0.7032
# Epoch 64/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3451 - accuracy: 0.7009 - val_loss: 0.3689 - val_accuracy: 0.7127
# Epoch 65/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3372 - accuracy: 0.7066 - val_loss: 0.3671 - val_accuracy: 0.7128
# Epoch 66/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3327 - accuracy: 0.7116 - val_loss: 0.3633 - val_accuracy: 0.7189
# Epoch 67/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3247 - accuracy: 0.7122 - val_loss: 0.3564 - val_accuracy: 0.7246
# Epoch 68/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.322 - accuracy: 0.7165 - val_loss: 0.3492 - val_accuracy: 0.7338
# Epoch 69/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3209 - accuracy: 0.7214 - val_loss: 0.3443 - val_accuracy: 0.7437
# Epoch 70/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3122 - accuracy: 0.7232 - val_loss: 0.3352 - val_accuracy: 0.7499
# Epoch 71/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3119 - accuracy: 0.7265 - val_loss: 0.3309 - val_accuracy: 0.7566
# Epoch 72/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3067 - accuracy: 0.7335 - val_loss: 0.3279 - val_accuracy: 0.7615
# Epoch 73/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.3023 - accuracy: 0.7431 - val_loss: 0.3212 - val_accuracy: 0.7664
# Epoch 74/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.297 - accuracy: 0.7492 - val_loss: 0.3167 - val_accuracy: 0.7717
# Epoch 75/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2931 - accuracy: 0.753 - val_loss: 0.3142 - val_accuracy: 0.7779
# Epoch 76/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2876 - accuracy: 0.7609 - val_loss: 0.3122 - val_accuracy: 0.7792
# Epoch 77/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.282 - accuracy: 0.7648 - val_loss: 0.3049 - val_accuracy: 0.7813
# Epoch 78/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2732 - accuracy: 0.7679 - val_loss: 0.3039 - val_accuracy: 0.7901
# Epoch 79/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2699 - accuracy: 0.7704 - val_loss: 0.2966 - val_accuracy: 0.7974
# Epoch 80/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.267 - accuracy: 0.7758 - val_loss: 0.2923 - val_accuracy: 0.8047
# Epoch 81/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2643 - accuracy: 0.7777 - val_loss: 0.2832 - val_accuracy: 0.8104
# Epoch 82/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2597 - accuracy: 0.7795 - val_loss: 0.2733 - val_accuracy: 0.8167
# Epoch 83/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2521 - accuracy: 0.7866 - val_loss: 0.2696 - val_accuracy: 0.8219
# Epoch 84/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2515 - accuracy: 0.787 - val_loss: 0.2654 - val_accuracy: 0.8272
# Epoch 85/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2436 - accuracy: 0.7871 - val_loss: 0.264 - val_accuracy: 0.8311
# Epoch 86/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2348 - accuracy: 0.7883 - val_loss: 0.2597 - val_accuracy: 0.8355
# Epoch 87/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.225 - accuracy: 0.7982 - val_loss: 0.2554 - val_accuracy: 0.8393
# Epoch 88/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2204 - accuracy: 0.7986 - val_loss: 0.2549 - val_accuracy: 0.8471
# Epoch 89/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2203 - accuracy: 0.8019 - val_loss: 0.2502 - val_accuracy: 0.8567
# Epoch 90/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2123 - accuracy: 0.8026 - val_loss: 0.2426 - val_accuracy: 0.8608
# Epoch 91/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.2059 - accuracy: 0.8078 - val_loss: 0.2342 - val_accuracy: 0.8701
# Epoch 92/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1997 - accuracy: 0.8096 - val_loss: 0.226 - val_accuracy: 0.8743
# Epoch 93/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1955 - accuracy: 0.8141 - val_loss: 0.2181 - val_accuracy: 0.8744
# Epoch 94/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1924 - accuracy: 0.8192 - val_loss: 0.2178 - val_accuracy: 0.8837
# Epoch 95/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1906 - accuracy: 0.8238 - val_loss: 0.2135 - val_accuracy: 0.8866
# Epoch 96/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1858 - accuracy: 0.8325 - val_loss: 0.2112 - val_accuracy: 0.8941
# Epoch 97/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1812 - accuracy: 0.8345 - val_loss: 0.2093 - val_accuracy: 0.8947
# Epoch 98/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1744 - accuracy: 0.8435 - val_loss: 0.2 - val_accuracy: 0.9031
# Epoch 99/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1728 - accuracy: 0.8522 - val_loss: 0.1903 - val_accuracy: 0.9079
# Epoch 100/100
# 3937/3937 [==============================] - 131s 32ms/step - loss: 0.1706 - accuracy: 0.857 - val_loss: 0.1902 - val_accuracy: 0.9084
